# %%
print("shivam shivhare")
# Out:
# shivam shivhare

# %%
5+5
# Out:
# 10

# %%
print("Nishi Joshi")
# Out:
# Nishi Joshi

# %%
9+12
# Out:
# 21

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
print("Nishi Joshi")
# Out:
# Nishi Joshi

# %%
name1 = "Anish"

# %%
name1
# Out:
# 'Anish'

# %%
price = 1200+ 100

# %%
price
# Out:
# 1300

# %%
age = 60
if age== 50:
  print("Age of person")
else:
  print("It is just a random number")
# Out:
# It is just a random number

# %%
type(name1)
# Out:
# str

# %%
com = 56 + 87j
type(com)
# Out:
# complex

# %%
accept = true
type(accept)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-51b353788fb7> in <cell line: 1>()
# ----> 1 accept = true
#       2 type(accept)
#
# NameError: name 'true' is not defined

# %%
accept = True
type(accept)
# Out:
# bool

# %%
name = "Anish"

# %%
name[2]
# Out:
# 'i'

# %%
name[-1]
# Out:
# 'h'

# %%
name = "Anish Joshi"

# %%
name[1:5]
# Out:
# 'nish'

# %%
name[:]
# Out:
# 'Anish Joshi'

# %%
name[0:-1]
# Out:
# 'Anish Josh'

# %%
del name
name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-3aec8ef3e8c7> in <cell line: 2>()
#       1 del name
# ----> 2 name
#
# NameError: name 'name' is not defined

# %%
name = 'shivam'
name = [ i for i in name]
name
# Out:
# ['s', 'h', 'i', 'v', 'a', 'm']

# %%
arr = [1,2,3,4,5,6]
arr = [ i for i in arr if i%2==0]

# %%
arr
# Out:
# [2, 4, 6]
