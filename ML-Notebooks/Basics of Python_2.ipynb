# %%
# TUPLES

(ORDERED, INDEXING , SLICING , IMMUTABLE, ALLOWS DUPLICATES)
# Out:
#   File "<ipython-input-1-64a44486442e>", line 3
#     (ORDERED, INDEXING , SLICING , IMMUTABLE, ALLOWS DUPLICATES)
#                                               ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
tuples = (1,'Anish')

# %%
tuples
# Out:
# (1, 'Anish')

# %%
tuples[1]
# Out:
# 'Anish'

# %%
tuples[-1]
# Out:
# 'Anish'

# %%
tuples[0]
# Out:
# 1

# %%
# SET - does not allow duplicates, unordered, no indexing and slicing, immutable

# %%
# dictionary - {key:value}

dict_1 = {1:'Ammu', 2: 'Smart', 3: 'VIT'}

# %%
dict_1
# Out:
# {1: 'Ammu', 2: 'Smart', 3: 'VIT'}

# %%
dict_2 = {1: ['Ammu','Appu']}

# %%
# only one key has to be used, but we assign multiple values in dictionary

# %%
dict_2.keys()
# Out:
# dict_keys([1])

# %%
dict_1.values()
# Out:
# dict_values(['Ammu', 'Smart', 'VIT'])

# %%
dict_1.items()
# Out:
# dict_items([(1, 'Ammu'), (2, 'Smart'), (3, 'VIT')])

# %%
dict[1]
# Out:
# dict[1]

# %%
dict_1[1
       ]
# Out:
# 'Ammu'

# %%
dict_1['name'] = ['Ammu', 'CHatterjee', 'Akash']

dict_1['name'][-3:]
# Out:
# ['Ammu', 'CHatterjee', 'Akash']

# %%
int a= int(input("Enter the value of a"))
# Out:
#   File "<ipython-input-20-6d213d672be4>", line 1
#     int a= int(input("Enter the value of a"))
#         ^
# SyntaxError: invalid syntax

# %%
a = int(input("Enter the value of a"))
# Out:
# Enter the value of a 12

# %%
if a>9:
  print("{} is the user input".format(a))
# Out:
# 12 is the user input
