# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/penguins_size.csv')
df
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 4    Adelie  Torgersen              36.7             19.3              193.0
# ..      ...        ...               ...              ...                ...
# 339  Gentoo     Biscoe               NaN              NaN                NaN
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# ...

# %%
df.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %% [markdown]
# ## UNIVARIATE ANALYSIS:

# %%
df.culmen_length_mm.plot()
# Out:
# <Axes: >

# %%
df.culmen_depth_mm.plot()
# Out:
# <Axes: >

# %%
df.body_mass_g.plo,.t()
# Out:
# <Axes: >

# %%
df.flipper_length_mm.plot()
# Out:
# <Axes: >

# %%
sns.displot(df.culmen_length_mm)

# %%
sns.distplot(df.culmen_length_mm)
# Out:
# <ipython-input-25-24e9b5890c61>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.culmen_length_mm)
# <Axes: xlabel='culmen_length_mm', ylabel='Density'>

# %%
sns.distplot(df.flipper_length_mm)
# Out:
# <ipython-input-26-4c42e92ff055>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.flipper_length_mm)
# <Axes: xlabel='flipper_length_mm', ylabel='Density'>

# %%
sns.distplot(df.body_mass_g)
# Out:
# <ipython-input-27-176964dae727>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.body_mass_g)
# <Axes: xlabel='body_mass_g', ylabel='Density'>

# %%
# Categorical Data

# %%
plt.pie(df.island.value_counts(),[0,0.1,0] ,labels = ['Biscoe','Dream','Torgersen'],autopct= "%1.1f%%",shadow=True,colors=['yellow','black','red'])
plt.show()

# %%
df.sex.value_counts()
# Out:
# MALE      179
# FEMALE    165
# Name: sex, dtype: int64

# %%
df.sex.isnull().sum()
# Out:
# 10

# %%
df.sex= df.sex.fillna('MALE')

# %%
df['sex'] = df['sex'].replace(['.'], 'MALE')

# %%
df.sex['.'] = 'MALE'
# Out:
# <ipython-input-39-3f815141871f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.sex['.'] = 'MALE'

# %%
plt.pie(df.sex.value_counts(),[0,0.1] ,labels = ['Male','Female'],autopct= "%1.1f%%",shadow=True,colors=['black','red'])
plt.show()

# %%
plt.pie(df.island.value_counts(),[0,0.1,0] ,labels = ['Adelie','Gentoo','Chinstrap'],autopct= "%1.1f%%",shadow=True,colors=['yellow','black','red'])
plt.show()

# %% [markdown]
# ### BIVARIATE ANALYSIS

# %%
plt.bar(df.culmen_length_mm,df.body_mass_g)
# Out:
# <BarContainer object of 344 artists>

# %%
plt.scatter(df.culmen_length_mm,df.body_mass_g)

# %%
sns.lineplot(x = df.flipper_length_mm, y= df.body_mass_g)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
sns.lineplot( x= df.culmen_length_mm	, y= df.culmen_depth_mm	)
# Out:
# <Axes: xlabel='culmen_length_mm', ylabel='culmen_depth_mm'>

# %%
plt.scatter(df.culmen_depth_mm,df.body_mass_g)

# %% [markdown]
# ### MULTIVARIATE ANALYSIS

# %%
sns.pairplot(df)

# %%
sns.heatmap(df.corr(),annot= True)
# Out:
# <ipython-input-51-0731fcb9e971>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot= True)
# <Axes: >

# %%
df.corr()
# Out:
# <ipython-input-55-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                    culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# culmen_length_mm           1.000000        -0.235053           0.656181
# culmen_depth_mm           -0.235053         1.000000          -0.583851
# flipper_length_mm          0.656181        -0.583851           1.000000
# body_mass_g                0.595110        -0.471916           0.871202
#
#                    body_mass_g
# culmen_length_mm      0.595110
# culmen_depth_mm      -0.471916
# flipper_length_mm     0.871202
# body_mass_g           1.000000

# %% [markdown]
# ### DESCRIPTIVE ANALYSIS

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   culmen_length_mm   342 non-null    float64
#  3   culmen_depth_mm    342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                344 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %% [markdown]
# ### Missing Values

# %%
df.isnull().any()
# Out:
# species              False
# island               False
# culmen_length_mm      True
# culmen_depth_mm       True
# flipper_length_mm     True
# body_mass_g           True
# sex                  False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# species              0
# island               0
# culmen_length_mm     2
# culmen_depth_mm      2
# flipper_length_mm    2
# body_mass_g          2
# sex                  0
# dtype: int64

# %%
df['culmen_length_mm'].fillna(df['culmen_length_mm'].median(),inplace=True)

# %%
df['culmen_depth_mm'].fillna(df['culmen_depth_mm'].median(),inplace=True)

# %%
df['flipper_length_mm'].fillna(df['flipper_length_mm'].median(),inplace=True)

# %%
df['body_mass_g'].fillna(df['body_mass_g'].median(),inplace=True)

# %%
df.isnull().sum()
# Out:
# species              0
# island               0
# culmen_length_mm     0
# culmen_depth_mm      0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# dtype: int64

# %% [markdown]
# ### Finding Outliers and replacing them

# %%
sns.boxplot(df.culmen_length_mm)
# Out:
# <Axes: >

# %%
sns.boxplot(df.culmen_depth_mm)
# Out:
# <Axes: >

# %%
sns.boxplot(df.flipper_length_mm)
# Out:
# <Axes: >

# %%
sns.boxplot(df.body_mass_g)
# Out:
# <Axes: >

# %%
# NO OUTLIERS DETECTED

# %% [markdown]
# ### Check correlation of independent of independent variables with target

# %%
df.corr()
# Out:
#                     species    island  culmen_length_mm  culmen_depth_mm  \
# species            1.000000 -0.635659          0.728706        -0.741282
# island            -0.635659  1.000000         -0.351189         0.567701
# culmen_length_mm   0.728706 -0.351189          1.000000        -0.235000
# culmen_depth_mm   -0.741282  0.567701         -0.235000         1.000000
# flipper_length_mm  0.850819 -0.562957          0.655858        -0.583832
# body_mass_g        0.747547 -0.558500          0.594925        -0.471942
# sex                0.010240  0.002893          0.322871         0.354791
#
#                    flipper_length_mm  body_mass_g       sex
# species                     0.850819     0.747547  0.010240
# island                     -0.562957    -0.558500  0.002893
# culmen_length_mm            0.655858     0.594925  0.322871
# culmen_depth_mm            -0.583832    -0.471942  0.354791
# flipper_length_mm           1.000000     0.871221  0.241941
# ...

# %% [markdown]
# ### Check for categorical data and perform encoding

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   culmen_length_mm   344 non-null    float64
#  3   culmen_depth_mm    344 non-null    float64
#  4   flipper_length_mm  344 non-null    float64
#  5   body_mass_g        344 non-null    float64
#  6   sex                344 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
# species, island, sex are categorical parameters. We will perform label encoding on them.

# %%
df.species= le.fit_transform(df.species)

# %%
df.island= le.fit_transform(df.island)

# %%
df.sex= le.fit_transform(df.sex)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    int64
#  1   island             344 non-null    int64
#  2   culmen_length_mm   344 non-null    float64
#  3   culmen_depth_mm    344 non-null    float64
#  4   flipper_length_mm  344 non-null    float64
#  5   body_mass_g        344 non-null    float64
#  6   sex                344 non-null    int64
# dtypes: float64(4), int64(3)
# memory usage: 18.9 KB

# %%
df.head()
# Out:
#    species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0        0       2             39.10             18.7              181.0
# 1        0       2             39.50             17.4              186.0
# 2        0       2             40.30             18.0              195.0
# 3        0       2             44.45             17.3              197.0
# 4        0       2             36.70             19.3              193.0
#
#    body_mass_g  sex
# 0       3750.0    1
# 1       3800.0    0
# 2       3250.0    0
# 3       4050.0    1
# 4       3450.0    0

# %% [markdown]
# ### SPLITTING THE DATA INTO DEPENDENT AND INDEPENDENT VARIABLES

# %%
Y = df.species
Y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: species, dtype: int64

# %%
X = df.drop(columns = ['species'],axis=1)
X.head()
# Out:
#    island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g  \
# 0       2             39.10             18.7              181.0       3750.0
# 1       2             39.50             17.4              186.0       3800.0
# 2       2             40.30             18.0              195.0       3250.0
# 3       2             44.45             17.3              197.0       4050.0
# 4       2             36.70             19.3              193.0       3450.0
#
#    sex
# 0    1
# 1    0
# 2    0
# 3    1
# 4    0

# %% [markdown]
# ### SCALING THE DATA

# %%
from sklearn.preprocessing import MinMaxScaler
scale = MinMaxScaler()

# %%
X_scaled = pd.DataFrame(scale.fit_transform(X),columns = X.columns)
X_scaled.head()
# Out:
#    island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g  \
# 0     1.0          0.254545         0.666667           0.152542     0.291667
# 1     1.0          0.269091         0.511905           0.237288     0.305556
# 2     1.0          0.298182         0.583333           0.389831     0.152778
# 3     1.0          0.449091         0.500000           0.423729     0.375000
# 4     1.0          0.167273         0.738095           0.355932     0.208333
#
#    sex
# 0  1.0
# 1  0.0
# 2  0.0
# 3  1.0
# 4  0.0

# %% [markdown]
# ### SPLITTING THE DATA INTO TRAINING AND TESTING

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X_scaled,Y,test_size=0.2,random_state=0)

# %% [markdown]
# ### Check the training and testing data shape

# %%
X_train.shape
# Out:
# (275, 6)

# %%
X_test.shape
# Out:
# (69, 6)
