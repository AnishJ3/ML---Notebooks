# %%
# discrete values - values without any bound.

# regression - discrete data.
# classification - predict animals, giving options.

# linear regression - make straight line
# logistic regression - make sigmoid curves, should not go with any extra value,
# for classification.

# decision tree - regression or classification , tree based algorithm.
# it breaks down a dataset into smaller and smaller subsets while at the same time
# an associated decision tree is incrementally developed.
# the final result is a tree with decision nodes and leaf nodes.

# undefitting - low testing and training accuracy.
# overfitting - training effieciency is higher but testing accuracy is lesser.
