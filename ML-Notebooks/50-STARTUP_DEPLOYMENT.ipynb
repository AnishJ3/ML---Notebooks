# %%
! pip install -q kaggle

# %%
# !mkdir ~/.kaggle # creating a kaggle directory

# %%
# !cp kaggle.json ~/.kaggle  # copying the json file to the directory

# %%
# !kaggle datasets download -d farhanmd29/50-startups # from kaggle dataset
# Out:
# ...
#   0% 0.00/1.30k [00:00<?, ?B/s]
# 100% 1.30k/1.30k [00:00<00:00, 2.44MB/s]

# %%
# !unzip /content/50-startups.zip
# Out:
# Archive:  /content/50-startups.zip
#   inflating: 50_Startups.csv

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/50_Startups.csv')
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
df.shape
# Out:
# (50, 5)

# %%
# !kaggle datasets download -d saumyamohandas/50-startup
# Out:
# ...
#   0% 0.00/1.37k [00:00<?, ?B/s]
# 100% 1.37k/1.37k [00:00<00:00, 2.85MB/s]

# %%
# !unzip /content/50-startup.zip
# Out:
# Archive:  /content/50-startup.zip
#   inflating: 50_Startups.csv

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-9063a9f0e032> in <cell line: 1>()
# ----> 1 y
#
# NameError: name 'y' is not defined

# %%
df= pd.read_csv('/content/50_Startups.csv')

# %%
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
df.shape
# Out:
# (108, 5)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df.State= le.fit_transform(df.State)

# %%
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend  State     Profit
# 0  165349.20       136897.80        471784.10      2  192261.83
# 1  162597.70       151377.59        443898.53      0  191792.06
# 2  153441.51       101145.55        407934.54      1  191050.39
# 3  144372.41       118671.85        383199.62      2  182901.99
# 4  142107.34        91391.77        366168.42      1  166187.94

# %%
# X and Y split

X = df.iloc[:,:-1]
X.head()
# Out:
#    R&D Spend  Administration  Marketing Spend  State
# 0  165349.20       136897.80        471784.10      2
# 1  162597.70       151377.59        443898.53      0
# 2  153441.51       101145.55        407934.54      1
# 3  144372.41       118671.85        383199.62      2
# 4  142107.34        91391.77        366168.42      1

# %%
y = df.Profit

# %%
y
# Out:
# 0      192261.83
# 1      191792.06
# 2      191050.39
# 3      182901.99
# 4      166187.94
#          ...
# 103    132602.65
# 104    129917.04
# 105    126992.93
# 106    125370.37
# 107    124266.90
# Name: Profit, Length: 108, dtype: float64

# %%
# Scaling the data

from sklearn.preprocessing import MinMaxScaler

scale = MinMaxScaler()

# %%
X_scaled = pd.DataFrame(scale.fit_transform(X),columns= X.columns)
X_scaled.head()
# Out:
#    R&D Spend  Administration  Marketing Spend  State
# 0   1.000000        0.651744         1.000000    1.0
# 1   0.983359        0.761972         0.940893    0.0
# 2   0.927985        0.379579         0.864664    0.5
# 3   0.873136        0.512998         0.812235    1.0
# 4   0.859438        0.305328         0.776136    0.5

# %%
# train test split

from sklearn.model_selection import train_test_split

# %%
X_train,X_test, y_train,y_test = train_test_split(X_scaled,y,test_size=0.2,random_state = 0)

# %%
X_train.shape
# Out:
# (86, 4)

# %%
X_test.shape
# Out:
# (22, 4)

# %%
# model building

from sklearn.linear_model import LinearRegression

lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
from sklearn.metrics import r2_score

# %%
print(r2_score(y_test,y_pred))
# Out:
# 0.9258962347553817

# %%
# testing with random variables

lr.predict([[0.873136,0.51296,0.812535,2]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([175138.58763744])

# %%
# saving the model we will will use pickle library

import pickle

# %%
pickle.dump(lr,open('startup.pkl','wb'))
